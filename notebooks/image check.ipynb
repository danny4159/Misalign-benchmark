# %% [markdown]
# # Summary

# %% [markdown]
# ```Objective```
#
# Check number of images per subject

# %% [markdown]
# ```Methods```
#
# todo

# %% [markdown]
# ```Results```
#
# todo

# %% [markdown]
# # Config

# %% [markdown]
# # Libs

# %%
# %load_ext autoreload
# %autoreload 2

import h5py
import numpy as np
import matplotlib.pyplot as plt
import torch
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # Analysis

# %%
with h5py.File('C:/Users/NUGURI/Workspace/misalign-benchmark/data/IXI/test/data.mat','r') as hf:
    print(hf.keys())
    print(hf['data_x'].shape)

    for n in range(10):
        test_np = hf['data_x'][:,:,91*n:91*(n+1),1][:]
        #plt.figure()
        #plt.imshow(test_np[128], cmap='gray')
        #plt.show()
# Out:
# <KeysViewHDF5 ['data_x', 'data_y']>
# (256, 256, 910, 3)

# %%
t = torch.tensor(test_np)

# %%
a = t.clone()
b = t.clone()
c = t.clone()
d = t.clone()

d = d[None]

# %%
assert a.ndim == b.ndim == c.ndim == d.ndim, "All input arrays must have the same number of dimensions"
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 assert a.ndim == b.ndim == c.ndim == d.ndim, "All input arrays must have the same number of dimensions"
#
# AssertionError: All input arrays must have the same number of dimensions
